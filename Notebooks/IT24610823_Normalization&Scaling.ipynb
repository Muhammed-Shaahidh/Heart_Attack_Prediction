# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammed-Shaahidh/Heart_Attack_Prediction/blob/master/Notebooks/IT24610823_Normalization%26Scaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import numpy as np

# %% [markdown]
# Load Dataset

# %%
url = "https://raw.githubusercontent.com/Muhammed-Shaahidh/Heart_Attack_Prediction/refs/heads/master/Data/data.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  num
# 0    ?           0
# 1    ?           0
# 2    ?           0
# 3    6           0
# 4    ?           0

# %% [markdown]
# Drop target column

# %%
df = df.rename(columns = {"num       " : "target"})
X = df.drop("target", axis = 1)
Y = df["target"]

# %% [markdown]
# Normalization (Min-Max Scaling:  values between 0 and 1)

# %%
X = X.replace('?', np.nan)
X.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca thal
# 0   28    1   2      130  132   0       2     185     0      0.0     2  0    7
# 1   29    1   2      120  243   0       0     160     0      0.0     2  0    7
# 2   29    1   2      140  230   0       0     170     0      0.0     2  0    7
# 3   30    0   1      170  237   0       1     170     0      0.0     2  0    6
# 4   31    0   2      100  219   0       1     150     0      0.0     2  0    7

# %%
min_max_scaler = MinMaxScaler()
X_min_max = min_max_scaler.fit_transform(X)

# %% [markdown]
# Convert back to Data Frame

# %%
X_min_max = pd.DataFrame(X_min_max, columns=X.columns)
print("First 5 rows after Normalization (0-1 Scale): ")
X_min_max.head()
# Out:
# First 5 rows after Normalization (0-1 Scale):
#         age  sex        cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0  0.000000  1.0  0.333333  0.351852  0.090734  0.0      1.0  0.953704    0.0
# 1  0.026316  1.0  0.333333  0.259259  0.305019  0.0      0.0  0.722222    0.0
# 2  0.026316  1.0  0.333333  0.444444  0.279923  0.0      0.0  0.814815    0.0
# 3  0.052632  0.0  0.000000  0.722222  0.293436  0.0      0.5  0.814815    0.0
# 4  0.078947  0.0  0.333333  0.074074  0.258687  0.0      0.5  0.629630    0.0
#
#    oldpeak  slope   ca  thal
# 0      0.0    0.5  0.0  1.00
# 1      0.0    0.5  0.0  1.00
# 2      0.0    0.5  0.0  1.00
# 3      0.0    0.5  0.0  0.75
# 4      0.0    0.5  0.0  1.00

# %% [markdown]
# Standardization (Z-score scaling)

# %%
standard_scaler = StandardScaler()
X_standard = standard_scaler.fit_transform(X)

# %% [markdown]
# Convert back to Data Frame

# %%
X_standard = pd.DataFrame(X_standard, columns=X.columns)
print("First 5 rows after Standardization (mean = 0, std = 1): ")
X_standard.head()
# Out:
# First 5 rows after Standardization (mean = 0, std = 1):
#         age       sex        cp  trestbps      chol       fbs   restecg  \
# 0 -2.542347  0.616670 -1.020259 -0.144514 -1.801169 -0.270172  3.879035
# 1 -2.414117  0.616670 -1.020259 -0.713285 -0.095541 -0.270172 -0.473775
# 2 -2.414117  0.616670 -1.020259  0.424256 -0.295299 -0.270172 -0.473775
# 3 -2.285888 -1.621613 -2.058170  2.130568 -0.187737 -0.270172  1.702630
# 4 -2.157658 -1.621613 -1.020259 -1.850826 -0.464326 -0.270172  1.702630
#
#     thalach     exang   oldpeak     slope   ca      thal
# 0  1.948871 -0.658898 -0.646074  0.180814  0.0  0.204811
# 1  0.885850 -0.658898 -0.646074  0.180814  0.0  0.204811
# 2  1.311059 -0.658898 -0.646074  0.180814  0.0  0.204811
# 3  1.311059 -0.658898 -0.646074  0.180814  0.0 -1.379778
# 4  0.460642 -0.658898 -0.646074  0.180814  0.0  0.204811
